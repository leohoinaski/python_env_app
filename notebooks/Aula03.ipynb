# %% [markdown]
# # Aula 03
#
# Nesta aula praticaremos a linguagem Python utilizando os pacotes Numpy e Pandas.
# Aprenderemos também como utilizar o pacote "os" para explorar diretórios e arquivos.

# %% [markdown]
# ## Numpy

# %%
# Importação do pacote numpy
import numpy as np

#==================== Geração de números aleatórios ===================
# : - ) 

# Valores máximos e mínimos
val_max, val_min = 10, 0.5
# Número de valores aleatórios
n = 1000

# Utilizando pacote numpy e função uniform que está dentro da subpacote random 
arr_aleatorio_real = np.random.uniform(val_min, val_max, n)

#print(arr_aleatorio_real)

# Utilizando pacote numpy e função randint que está dentro da subpacote random 
arr_aleatorio_inteiro = np.random.randint(val_min, val_max, n)

#print(arr_aleatorio_inteiro)

# %%
# Verificando o tamanho da matriz arr_aleatorio_real
# shape
print(arr_aleatorio_real.shape)
print(np.shape(arr_aleatorio_real))

# size
print(arr_aleatorio_real.size)


# Utilizando o reshape para formatar um vetor em uma matriz 2 linhas e n colunas
mat = arr_aleatorio_real.reshape(2,-1)
print(np.shape(mat))
print(mat.size)
#print(mat)
# Out:
# (1000,)
# (1000,)
# 1000
# (2, 500)
# 1000

# %%
# Multiplicação de matrizes

# Multiplicação com arrays do mesmo tamanho
arr_resultado = arr_aleatorio_inteiro*arr_aleatorio_real

# Multiplicação com arrays de diferentes dimensões -ERRADO
multiplicador = np.random.randint(1,10,2)

arr_resultado2 =[]
for multi in multiplicador:
    print(multi)
    arr_resultado2.append(arr_aleatorio_inteiro*multi)
#print(arr_resultado2)

arr_resultado3 = np.concatenate(arr_resultado2)
print(arr_resultado3.shape)

arr_resultado4 = np.vstack(arr_resultado2)
print(arr_resultado4.shape)

arr_resultado5 = np.hstack(arr_resultado2)
print(arr_resultado5.shape)

arr_resultado6 = arr_resultado4.transpose()
print(arr_resultado6.shape)

arr_resultado7 = np.random.rand(10,10,10)
print(arr_resultado7.shape)
# Out:
# 8
# 5
# (2000,)
# (2, 1000)
# (2000,)
# (1000, 2)
# (10, 10, 10)

# %%
# acessando valores da matriz
# considerando que arr_resultado7 é uma matriz de temperatura com as dimensões [lat,lon,tempo],
# determine a temperatura para o tempo igual a 1 em todas as latitudes e longitudes
arr_resultado7[:,:,0]

# para todas as longitudes e primeira latitude e primeiro tempo
arr_resultado7[0,:,0]

# todas as latitudes, primeira longitude e último tempo
arr_resultado7[:,0,-1]
np.shape(arr_resultado7)[2]
arr_resultado7[:,0,np.shape(arr_resultado7)[2]-1]

# Para um ponto lat lon no espaço e todo tempo
arr_resultado7[2,2,:]

# Uma região no espaço
arr_resultado7[2:4,4:6,1]
# Out:
# array([[0.44339946, 0.26111383],
#        [0.79653672, 0.81301964]])

# %%
# Estatísticas com numpy

# Mínimo considerando todas as dimensões
min_absoluto = arr_resultado7.min()
print(min_absoluto)

# Mínimo para cada ponto (lat,lon) considerando todos os tempos
min_latlon = arr_resultado7.min(axis=2)
min_latlon = np.min(arr_resultado7,axis=2)
#print(min_latlon)

# atribuindo um valor NaN dentro da matriz em algum lugar
arr_resultado7[2,3,1] = np.nan
#print(arr_resultado7)

# Mínimo com nan
# Utilizaremos o dados do https://hoinaski.prof.ufsc.br/files/ para trabalharmos na discplina.
# Baixe um arquivo na pasta RQAr_2025/MQAr/MP25/*

# %%
# Importando o pandas
import pandas as pd

# Utilizando o pandas para abrir um arquivo
df = pd.read_csv(r"C:\Users\Leonardo.Hoinaski\Downloads\SP0063RA002.csv")

# pré-visualização
df.head()
# Out:
#               DATETIME   ANO  MES  DIA  HORA  VALOR  VALOR_ORIGINAL UNIDADE  \
# 0  2017-05-29 01:00:00  2017    5   29     1   42.0            42.0   µg/m3
# 1  2017-05-29 02:00:00  2017    5   29     2   49.0            49.0   µg/m3
# 2  2017-05-29 03:00:00  2017    5   29     3   42.0            42.0   µg/m3
# 3  2017-05-29 04:00:00  2017    5   29     4   34.0            34.0   µg/m3
# 4  2017-05-29 05:00:00  2017    5   29     5   26.0            26.0   µg/m3
#
#    QAQC_INTERNO  QAQC_MMA
# 0          True      True
# 1          True      True
# 2          True      True
# 3          True      True
# 4          True      True

# %%
# Indexação com pandas

# Todas as linhas e segunda coluna
df.iloc[:,1]

# Todas as colunas e primeira linha
df.iloc[0,:]

# Usando loc
df.loc[:,'ANO']

# Usando apenas o colchete
df['ANO']

# Extrair nome das colunas
df.columns

# Acessando o valor da terceira coluna
df.loc[:,df.columns[2]]
# Out:
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5
#         ..
# 72523    9
# 72524    9
# 72525    9
# 72526    9
# 72527    9
# Name: MES, Length: 72528, dtype: int64

# %%
# Inserindo um valor
df.loc[1,'VALOR'] = -1
print(df['VALOR'])
# Out:
# 0        42.0
# 1        -1.0
# 2        42.0
# 3        34.0
# 4        26.0
#          ...
# 72523    18.0
# 72524     1.0
# 72525     6.0
# 72526     4.0
# 72527    11.0
# Name: VALOR, Length: 72528, dtype: float64

# %%
# Substituindo valores ruins
df.loc[df['VALOR']<0,'VALOR'] = np.nan

df['VALOR']
# Out:
# 0        42.0
# 1         NaN
# 2        42.0
# 3        34.0
# 4        26.0
#          ...
# 72523    18.0
# 72524     1.0
# 72525     6.0
# 72526     4.0
# 72527    11.0
# Name: VALOR, Length: 72528, dtype: float64

# %%
# Estatística com pandas
df.describe()
# Out:
#                 ANO           MES           DIA          HORA         VALOR  \
# count  72528.000000  72528.000000  72528.000000  72528.000000  65961.000000
# mean    2021.041805      6.540426     15.725692     11.500000     16.366686
# std        2.417737      3.397025      8.817042      6.922234     13.165943
# min     2017.000000      1.000000      1.000000      0.000000      1.000000
# 25%     2019.000000      4.000000      8.000000      5.750000      7.000000
# 50%     2021.000000      7.000000     16.000000     11.500000     13.000000
# 75%     2023.000000      9.000000     23.000000     17.250000     22.000000
# max     2025.000000     12.000000     31.000000     23.000000    234.000000
#
#        VALOR_ORIGINAL
# count    66721.000000
# mean        16.180992
# std         13.205918
# min          0.000000
# 25%          7.000000
# 50%         13.000000
# 75%         21.000000
# max        234.000000

# %%
print(df['VALOR'].mean())
# Out:
# 16.366686375282363

# %%
df.loc[df['VALOR']>np.nanpercentile(df['VALOR'],99),'VALOR'] = np.nan
df.describe()
# Out:
#                 ANO           MES           DIA          HORA         VALOR  \
# count  72528.000000  72528.000000  72528.000000  72528.000000  65315.000000
# mean    2021.041805      6.540426     15.725692     11.500000     15.782699
# std        2.417737      3.397025      8.817042      6.922234     11.768545
# min     2017.000000      1.000000      1.000000      0.000000      1.000000
# 25%     2019.000000      4.000000      8.000000      5.750000      7.000000
# 50%     2021.000000      7.000000     16.000000     11.500000     13.000000
# 75%     2023.000000      9.000000     23.000000     17.250000     21.000000
# max     2025.000000     12.000000     31.000000     23.000000     63.000000
#
#        VALOR_ORIGINAL
# count    66721.000000
# mean        16.180992
# std         13.205918
# min          0.000000
# 25%          7.000000
# 50%         13.000000
# 75%         21.000000
# max        234.000000

# %%
#Plotagem
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2)
df['VALOR'].plot(ax=ax[0],linewidth = 0.1)
df['VALOR'].hist(ax=ax[1])

fig, ax = plt.subplots()
ax.boxplot(df.loc[~np.isnan(df['VALOR']),'VALOR'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2233d03bd90>,
#   <matplotlib.lines.Line2D at 0x2233d03bed0>],
#  'caps': [<matplotlib.lines.Line2D at 0x2233d070050>,
#   <matplotlib.lines.Line2D at 0x2233d070190>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2233d03bc50>],
#  'medians': [<matplotlib.lines.Line2D at 0x2233d0702d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2233d070410>],
#  'means': []}

# %%
# Operações com datetime

df['DATETIME'] = pd.to_datetime(df['DATETIME'])
df['DATETIME']
# Out:
# 0       2017-05-29 01:00:00
# 1       2017-05-29 02:00:00
# 2       2017-05-29 03:00:00
# 3       2017-05-29 04:00:00
# 4       2017-05-29 05:00:00
#                 ...
# 72523   2025-09-05 20:00:00
# 72524   2025-09-05 21:00:00
# 72525   2025-09-05 22:00:00
# 72526   2025-09-05 23:00:00
# 72527   2025-09-06 00:00:00
# Name: DATETIME, Length: 72528, dtype: datetime64[ns]

# %%
fig, ax = plt.subplots()
ax.plot(df.DATETIME, df['VALOR'])

# %%
# Criando um vetor datetime a partir de colunas ANO, MES, DIA, HORA
data = {'year': df.ANO,
        'month': df.MES,
        'day': df.DIA,
        'hour': df.HORA}
df_datetime = pd.DataFrame(data)

df['datetime_column'] = pd.to_datetime(df_datetime[['year', 'month', 'day', 'hour']])

# %%
df[['ANO','MES', 'VALOR']].groupby(['ANO', 'MES']).mean().plot()
# Out:
# <Axes: xlabel='ANO,MES'>

# %%
# Lendo outro arquivo
df2 = pd.read_csv(r"C:\Users\Leonardo.Hoinaski\Downloads\RJ0069RA002.csv")
df2['DATETIME'] = pd.to_datetime(df2['DATETIME'])

fig, ax = plt.subplots()

ax.plot(df.DATETIME, df.VALOR, linewidth = 0.1)
ax.plot(df2.DATETIME, df2.VALOR, linewidth = 0.1)

# %%
# Automatizando com o pacote os
# Out:
# ['RJ0069RA002.csv', 'SP0063RA002.csv']

# %%
import os 
files = os.listdir(r"C:\Users\Leonardo.Hoinaski\Documents\python_env_app\dados")
files = [ fname for fname in files if fname.endswith('.csv')]
files
for file in files:
    print(file)
    df = pd.read_csv(r"C:\Users\Leonardo.Hoinaski\Documents\python_env_app\dados"+'/'+file)
    df['DATETIME'] = pd.to_datetime(df['DATETIME'])
    fig, ax = plt.subplots()
    ax.plot(df.DATETIME, df.VALOR, linewidth = 0.1)
# Out:
# RJ0069RA002.csv
# RJ0216RA002.csv
# SP0063RA002.csv
